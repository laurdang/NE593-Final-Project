# %% [markdown]
# # Train/Set up model

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define important model parameters and variables
N_AL = 50  # number of Antennal Lobe neurons
N_ODOR_ACTIVE = 20  # how many AL neurons each odor activates
N_MB = 2000  # number of Mushroom Body neurons
N_OUTPUT = 1  # single output neuron for avoidance decision
rng = np.random.default_rng(seed=123)  # for reproducibility

# Store activity history for plotting
output_history = [] 
w_mb_out_history = []

# Initialise our two odors
def make_odor(N_AL, N_ODOR_ACTIVE, seed=None):
    """
    Returns a binary vector of length n_al
    with n_active neurons set to 1.
    Each odor activates a random non-overlapping subset.
    """
    rng = np.random.default_rng(seed)
    odor = np.zeros(N_AL)
    active_indices = rng.choice(N_AL, size=N_ODOR_ACTIVE, replace=False) # Select random neurons to activate
    odor[active_indices] = 1 # Set activated neurons to 1 to create binary vector (single odor pattern)
    return odor

# %% [markdown]
# ## Define activity related functions

# %%
def sigmoid(x):
    return 1/ (1+np.exp(-x))


def forward(odor_pattern, w_al_mb, w_mb_out, dopamine):
    """
    One forward pass through the network.
    Returns output neuron activity.

    odor_pattern: binary vector of length n_al, represents either a single odor or combination of two odors
    dopamine: 1.0 if shock present, 0.0 if not
    """
    
    # AL -> MB
    mb_input = odor_pattern @ w_al_mb # Multiply input by weight matrix of AL->MB synapses
    mb_activity = sigmoid(mb_input) # Compute MB activity

    # # OPTIONAL: Apply inhibition: suppresses weakly activated MB neurons
    # # Simple approximation of paper's inhibitory neuron
    # inhibition_threshold = np.percentile(mb_activity, 70)
    # mb_activity[mb_activity < inhibition_threshold] = 0.0

    # MB -> Output
    out_input = np.dot(w_mb_out, mb_activity) # Multiply MB activity by weight matrix of MB->Output synapses
    out_activity = sigmoid(out_input) # Compute output activity (avoidance decision)

    return mb_activity, out_activity


def avoidance(out_activity, threshold=0.7):
    """
    Determines output behavior based on output neuron activity (avoid or not avoid).

    out_activity: activity of the output neuron (between 0 and 1, set to 0.7 based on paper's results)
    threshold: output activity above which we consider the fly to be avoiding
    """
    return out_activity > threshold

# %% [markdown]
# ## Define weight update functions

# %%
## WIP

# %% [markdown]
# # Test model (experimental trials)

# %% [markdown]
# ### Initialise inputs, weights, and variables to track results

# %%
# Make two distinct odors
odor1 = make_odor(seed=42)
odor2 = make_odor(seed=99)
assert np.array_equal(odor1, odor2) == False # Verify they are non-overlapping

# Initialise weight matrices (0-1 random weights)
# AL -> MB: sparse random connections
w_al_mb = rng.random((N_AL, N_MB))

# MB -> Output: single output neuron
w_mb_out = rng.random(N_MB) 

# Check shapes of our variables
print("Odor shape:", odor1.shape)
print("AL->MB weights shape:", w_al_mb.shape)
print("MB->Output weights shape:", w_mb_out.shape)
# print("AL->MB weights sample:", w_al_mb[:5, :5])  
# print("MB->Output weights sample:", w_mb_out[:5])

# Set experimental phases
N_TRIALS_PHASE1 = 10   # odor1 + shock (first order conditioning)
N_TRIALS_PHASE2 = 10   # odor1 + odor2 (odor pairing)
N_TRIALS_PHASE3 = 5    # odor2 alone (test)

# Set up storage to track output of trials for each phase
output_history = {"phase1": [], "phase2": [], "phase3": []}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Make two distinct odors
# ----> 2 odor1 = make_odor(seed=42)
#       3 odor2 = make_odor(seed=99)
#       4 assert np.array_equal(odor1, odor2) == False # Verify they are non-overlapping
#
# TypeError: make_odor() missing 2 required positional arguments: 'N_AL' and 'N_ODOR_ACTIVE'

# %% [markdown]
# ### Start trials

# %%
# --- Phase 1: First order conditioning ---

print("Phase 1: odor1 + shock")
for trial in range(N_TRIALS_PHASE1):
    mb_activity, out_activity = forward(w_al_mb, w_mb_out, odor1, dopamine=1.0) # Complete forward pass with odor1 and shock
    output_history["phase1"].append(out_activity) # Store output

    # Print trial results
    print(f"  Trial {trial + 1}: output={out_activity:.3f}, "
              f"avoidance={avoidance(out_activity)}")

# Plot results for Phase 1
plt.plot(output_history["phase1"], label="Phase 1: Odor1 + Shock")
plt.xlabel("Trial")
plt.ylabel("Output Neuron Activity")
plt.title("Output Neuron Activity During Phase 1")
plt.show()
# Out:
# Phase 1: odor1 + shock
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 # --- Phase 1: First order conditioning ---
#       3 print("Phase 1: odor1 + shock")
# ----> 4 for trial in range(N_TRIALS_PHASE1):
#       5     mb_activity, out_activity = forward(w_al_mb, w_mb_out, odor1, dopamine=1.0) # Complete forward pass with odor1 and shock
#       6     output_history["phase1"].append(out_activity) # Store output
#
# NameError: name 'N_TRIALS_PHASE1' is not defined

# %%
output_history["phase1"].append(1)
output_history["phase1"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 output_history["phase1"].append(1)
#       2 output_history["phase1"]
#
# TypeError: list indices must be integers or slices, not str
